# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthanarangaraju/data-Science/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#play with the data

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/Datasets/main/titanic-training-data.csv")

# %%
df.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# ...

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 865          866         1       2  Bystrom, Mrs. (Karolina)  female  42.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 865      0      0  236852  13.0   NaN        S

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 841          842         0       2                   Mudd, Mr. Thomas Charles
# 772          773         0       2                          Mack, Mrs. (Mary)
# 749          750         0       3                    Connaghton, Mr. Michael
# 763          764         1       1  Carter, Mrs. William Ernest (Lucile Polk)
# 764          765         0       3                     Eklund, Mr. Hans Linus
#
#         Sex   Age  SibSp  Parch       Ticket     Fare    Cabin Embarked
# 841    male  16.0      0      0  S.O./P.P. 3   10.500      NaN        S
# 772  female  57.0      0      0  S.O./P.P. 3   10.500      E77        S
# 749    male  31.0      0      0       335097    7.750      NaN        Q
# 763  female  36.0      1      2       113760  120.000  B96 B98        S
# 764    male  16.0      0      0       347074    7.775      NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
labels=['k','s','t','u']
sample_lst=np.array([1,2,3,4])
samp=[100,200,300,400]
dict={'k':10,'s':20,'t':30,'u':40}

# %%
pd.Series(data=samp)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %%
pd.Series(data=samp,index=labels)
# Out:
# k    100
# s    200
# t    300
# u    400
# dtype: int64

# %%
pd.Series(dict)
# Out:
# k    10
# s    20
# t    30
# u    40
# dtype: int64

# %%
pd.Series(samp)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %%
pd.Series(samp,labels)
# Out:
# k    100
# s    200
# t    300
# u    400
# dtype: int64

# %%
s1=pd.Series([1,2,3,4],['A','B','C','D'])
s1
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
s2=pd.Series([11,21,3,4],['A','B','E','D'])
s2
# Out:
# A    11
# B    21
# E     3
# D     4
# dtype: int64

# %%
s1+s2
# Out:
# A    12.0
# B    23.0
# C     NaN
# D     8.0
# E     NaN
# dtype: float64

# %%
df1=pd.DataFrame(np.random.rand(3,3),index='A B C'.split(),columns='c1 c2 c3'.split())
df1
# Out:
#          c1        c2        c3
# A  0.250516  0.172902  0.828243
# B  0.134620  0.172395  0.789703
# C  0.327771  0.961363  0.006700

# %%
df1[["c1","c2"]]
# Out:
#          c1        c2
# A  0.250516  0.172902
# B  0.134620  0.172395
# C  0.327771  0.961363

# %%
df1["c1"]
# Out:
# A    0.250516
# B    0.134620
# C    0.327771
# Name: c1, dtype: float64

# %%
df1["c4"]=df1["c1"]+df1["c2"]
df1
# Out:
#          c1        c2        c3        c4
# A  0.250516  0.172902  0.828243  0.423418
# B  0.134620  0.172395  0.789703  0.307015
# C  0.327771  0.961363  0.006700  1.289134

# %%
df2={'ID':[1,2,3,4],'name':["keerthi","harsha","sanju","sai"]}
df=pd.DataFrame(df2)
df
# Out:
#    ID     name
# 0   1  keerthi
# 1   2   harsha
# 2   3    sanju
# 3   4      sai

# %%
df["ID"]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: ID, dtype: int64

# %%
df.drop(3)
# Out:
#       name
# 0  keerthi
# 1   harsha
# 2    sanju

# %%
df
# Out:
#       name
# 0  keerthi
# 1   harsha
# 2    sanju
# 3      sai
